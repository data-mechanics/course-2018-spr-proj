# %%
# ####################################### Gonna get us some DATA #######################################################
# ################ Data about Hubway Stations, Electric Charging Stations, and Open Spaces in Boston ###################


import urllib.request
import json
import dml
import prov.model
import datetime
import uuid
import geojson
import csv


def fetch_json(url, item):
    print("Downloading " + str(item) + " Dataset from: " + str(url))
    response = urllib.request.urlopen(url).read().decode("utf-8")
    r = json.loads(response)
    return r


def fetch_geojson(url, item):
    print("Downloading " + str(item) + " Dataset from: " + str(url))
    response = urllib.request.urlopen(url).read().decode("utf-8")
    r = geojson.loads(response)
    rdict = dict(r)
    rlist = rdict['features']
    return rlist


class getdata(dml.Algorithm):
    contributor = 'jhs2018_rpm1995'
    reads = []
    writes = ['jhs2018_rpm1995.hubway',
              'jhs2018_rpm1995.charge',
              'jhs2018_rpm1995.trees',
              'jhs2018_rpm1995.budget',
              'jhs2018_rpm1995.openspaces']

    @staticmethod
    def execute(trial=False):
        # Retrieve datasets
        startTime = datetime.datetime.now()

        # Set up the database connection.
        client = dml.pymongo.MongoClient()
        repo = client.repo
        repo.authenticate('jhs2018_rpm1995', 'jhs2018_rpm1995')

        # This fetches a dataset with details about Hubway stations in Boston
        r = fetch_geojson('http://bostonopendata-boston.opendata.arcgis.com/datasets'
                          '/ee7474e2a0aa45cbbdfe0b747a5eb032_0.geojson', "Hubway Stations")
        repo.dropCollection("hubway")
        repo.createCollection("hubway")
        repo['jhs2018_rpm1995.hubway'].insert_many(r)

#         # This fetches a dataset with details about Trees in Boston
#         r = fetch_geojson('http://datamechanics.io/data/Trees%20(1).geojson', "Trees")
#         repo.dropCollection("trees")
#         repo.createCollection("trees")
#         repo['jhs2018_rpm1995.trees'].insert_many(r)

        # This fetches a dataset with details about Charging Stations in Boston
        r = fetch_json('https://boston.opendatasoft.com/explore/dataset/charging-stations/download/?format=json'
                       '&timezone=America/New_York', "Charging Stations")
        repo.dropCollection("charge")
        repo.createCollection("charge")
        repo['jhs2018_rpm1995.charge'].insert_many(r)

#         # This fetches a dataset with details about Open Spaces in Boston
#         r = fetch_geojson('http://bostonopendata-boston.opendata.arcgis.com/datasets/2868d370c55d4d458d4ae2224ef8cddd_7'
#                           '.geojson', "Open Spaces")
#         repo.dropCollection("openspaces")
#         repo.createCollection("openspaces")
#         repo['jhs2018_rpm1995.openspaces'].insert_many(r)

        # This fetches a dataset with details about Budget Facilities in Boston
#         r = fetch_geojson('http://bostonopendata-boston.opendata.arcgis.com/datasets/106ab2544b3d4038ad110b531777931e_0.geojson', "Budget Facilities")
        url = 'http://datamechanics.io/data/Budget_Facilities_FY2017.csv'
        response = urllib.request.urlopen(url).read().decode("utf-8")
        reader = csv.DictReader(response.splitlines())
        dicky = []
        for row in reader:
            print(row)
            dicky.append(row)
        repo.dropCollection("budget")
        repo.createCollection("budget")
        repo['jhs2018_rpm1995.budget'].insert_many(dicky)

        repo.logout()

        endTime = datetime.datetime.now()

        return {"start": startTime, "end": endTime}

    @staticmethod
    def provenance(doc=prov.model.ProvDocument(), startTime=None, endTime=None):

            # Create the provenance document describing everything happening
            # in this script. Each run of the script will generate a new
            # document describing that invocation event.

        client = dml.pymongo.MongoClient()
        repo = client.repo
        repo.authenticate('jhs2018_rpm1995', 'jhs2018_rpm1995')
        doc.add_namespace('alg', 'http://datamechanics.io/algorithm/')  # The scripts are in <folder>#<filename> format.
        doc.add_namespace('dat', 'http://datamechanics.io/data/')  # The data sets are in <user>#<collection> format.
        doc.add_namespace('ont', 'http://datamechanics.io/ontology#')  # 'Extension', 'DataResource', 'DataSet',
        # 'Retrieval', 'Query', or 'Computation'.
        doc.add_namespace('log', 'http://datamechanics.io/log/')  # The event log.
        doc.add_namespace('bwod', 'https://boston.opendatasoft.com/explore/dataset/boston-neighborhoods/')  # Boston
        # Wicked Open Data
        doc.add_namespace('hub', 'http://bostonopendata-boston.opendata.arcgis.com/datasets')  # Boston Open Data
        doc.add_namespace('tree', 'http://datamechanics.io/data')
        doc.add_namespace('charge', 'http://bostonopendata-boston.opendata.arcgis.com/datasets')
        doc.add_namespace('openspace', 'http://bostonopendata-boston.opendata.arcgis.com/datasets')
        doc.add_namespace('budget', 'http://bostonopendata-boston.opendata.arcgis.com/datasets')

        this_script = doc.agent('alg:jhs2018_rpm1995#getdata',
                                {prov.model.PROV_TYPE: prov.model.PROV['SoftwareAgent'], 'ont:Extension': 'py'})

# #######

        resource_hubway = doc.entity('hub: geojson', {'prov:label': 'Hubway stations in Boston',
                                                      prov.model.PROV_TYPE: 'ont:DataResource', 'ont:Extension':
                                                          'geojson'})
        get_hubway = doc.activity('log:uuid' + str(uuid.uuid4()), startTime, endTime)
        doc.wasAssociatedWith(get_hubway, this_script)
        doc.usage(get_hubway, resource_hubway, startTime, None, {prov.model.PROV_TYPE: 'ont:Retrieval'})

        resource_trees = doc.entity('tree: geojson', {'prov:label': 'Trees in Boston',
                                                prov.model.PROV_TYPE: 'ont:DataResource', 'ont:Extension': 'geojson'})
        get_trees = doc.activity('log:uuid' + str(uuid.uuid4()), startTime, endTime)
        doc.wasAssociatedWith(get_trees, this_script)
        doc.usage(get_trees, resource_trees, startTime, None, {prov.model.PROV_TYPE: 'ont:Retrieval'})

        resource_charge = doc.entity('charge: json', {'prov:label': 'Charging Stations in Boston',
                                                      prov.model.PROV_TYPE: 'ont:DataResource', 'ont:Extension':
                                                      'json'})
        get_charge = doc.activity('log:uuid' + str(uuid.uuid4()), startTime, endTime)
        doc.wasAssociatedWith(get_charge, this_script)
        doc.usage(get_charge, resource_charge, startTime, None, {prov.model.PROV_TYPE: 'ont:Retrieval'})
        
        resource_budget = doc.entity('budget: geojson', {'prov:label': 'Budget Facilities in Boston',
                                                      prov.model.PROV_TYPE: 'ont:DataResource', 'ont:Extension':
                                                      'geojson'})
        get_budget = doc.activity('log:uuid' + str(uuid.uuid4()), startTime, endTime)
        doc.wasAssociatedWith(get_budget, this_script)
        doc.usage(get_budget, resource_budget, startTime, None, {prov.model.PROV_TYPE: 'ont:Retrieval'})

        resource_openspaces = doc.entity('openspace: geojson', {'prov:label': 'Open Spaces in Boston',
                                                                prov.model.PROV_TYPE: 'ont:DataResource',
                                                                'ont:Extension':
                                                                'geojson'})
        get_openspaces = doc.activity('log:uuid' + str(uuid.uuid4()), startTime, endTime)
        doc.wasAssociatedWith(get_openspaces, this_script)
        doc.usage(get_openspaces, resource_openspaces, startTime, None, {prov.model.PROV_TYPE: 'ont:Retrieval'})
# #######

        hubway = doc.entity('dat:jhs2018_rpm1995hubway', {prov.model.PROV_LABEL: 'hubway', prov.model.PROV_TYPE: 'ont:DataSet'})
        doc.wasAttributedTo(hubway, this_script)
        doc.wasGeneratedBy(hubway, get_hubway, endTime)
        doc.wasDerivedFrom(hubway, resource_hubway, get_hubway, get_hubway, get_hubway)

        trees = doc.entity('dat:jhs2018_rpm1995trees', {prov.model.PROV_LABEL: 'trees', prov.model.PROV_TYPE: 'ont:DataSet'})
        doc.wasAttributedTo(trees, this_script)
        doc.wasGeneratedBy(trees, get_trees, endTime)
        doc.wasDerivedFrom(trees, resource_trees, get_trees, get_trees, get_trees)

        charge = doc.entity('dat:jhs2018_rpm1995charge',
                            {prov.model.PROV_LABEL: 'charge', prov.model.PROV_TYPE: 'ont:DataSet'})
        doc.wasAttributedTo(charge, this_script)
        doc.wasGeneratedBy(charge, get_charge, endTime)
        doc.wasDerivedFrom(charge, resource_charge, get_charge, get_charge, get_charge)
        
        budget = doc.entity('dat:jhs2018_rpm1995budget',
                            {prov.model.PROV_LABEL: 'budget', prov.model.PROV_TYPE: 'ont:DataSet'})
        doc.wasAttributedTo(budget, this_script)
        doc.wasGeneratedBy(budget, get_budget, endTime)
        doc.wasDerivedFrom(budget, resource_budget, get_budget, get_budget, get_budget)

        openspaces = doc.entity('dat:jhs2018_rpm1995openspaces',
                                {prov.model.PROV_LABEL: 'openspaces', prov.model.PROV_TYPE: 'ont:DataSet'})
        doc.wasAttributedTo(openspaces, this_script)
        doc.wasGeneratedBy(openspaces, get_openspaces, endTime)
        doc.wasDerivedFrom(openspaces, resource_openspaces, get_openspaces, get_openspaces, get_openspaces)

        repo.logout()

        return doc


getdata.execute()
doc = getdata.provenance()
print(doc.get_provn())
print(json.dumps(json.loads(doc.serialize()), indent=4))

# eof
# Out:
# Downloading Hubway Stations Dataset from: http://bostonopendata-boston.opendata.arcgis.com/datasets/ee7474e2a0aa45cbbdfe0b747a5eb032_0.geojson
# Downloading Charging Stations Dataset from: https://boston.opendatasoft.com/explore/dataset/charging-stations/download/?format=json&timezone=America/New_York
# OrderedDict([('\ufeffX', '-71.06962854207255'), ('Y', '42.339609596150176'), ('OBJECTID', '1'), ('Longitude', '-71.0696279488279'), ('Latitude', '42.3396009272291'), ('FID', '0'), ('OBJECTID_1', '2'), ('OBJECTID_12', '100'), ('ID', '56'), ('City_Department', 'Police Department'), ('Capital_Project_Number', 'CPD23867'), ('Capital_Asset_Name', 'Area D-4 Station'), ('Capital_Project_Title', 'Area A-1 and Area D-4 Stations'), ('ID1', '56'), ('Project_Description', 'Install new roofs at two police stations. Replace windows at Area A-1 Station and make foundation and terrace masonry repairs.'), ('Neighborhood', 'South End'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '125000'), ('Total_Project_Budget', '2500000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 2'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.150476885183906'), ('Y', '42.34941534142807'), ('OBJECTID', '2'), ('Longitude', '-71.1504762650063'), ('Latitude', '42.3494066733083'), ('FID', '1'), ('OBJECTID_1', '4'), ('OBJECTID_12', '102'), ('ID', '58'), ('City_Department', 'Police Department'), ('Capital_Project_Number', 'CPD23865'), ('Capital_Asset_Name', 'Area D-14 Station'), ('Capital_Project_Title', 'Area D-14 Station'), ('ID1', '58'), ('Project_Description', 'Install new windows on the second floor.'), ('Neighborhood', 'Allston/Brighton'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '300000'), ('Total_Project_Budget', '360000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 9'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-70.992251508666357'), ('Y', '42.304982969027009'), ('OBJECTID', '3'), ('Longitude', '-70.9922509430032'), ('Latitude', '42.3049743042473'), ('FID', '2'), ('OBJECTID_1', '6'), ('OBJECTID_12', '104'), ('ID', '64'), ('City_Department', 'Police Department'), ('Capital_Project_Number', 'CPD20654'), ('Capital_Asset_Name', 'Police Gun Range'), ('Capital_Project_Title', 'Gun Range at Moon Island'), ('ID1', '64'), ('Project_Description', 'Design and construct a facility to support administrative and training requirements including appropriate environmental mitigation.'), ('Neighborhood', 'Harbor Islands'), ('Project_Status', 'In Design'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '1939686'), ('Total_Project_Budget', '2800000'), ('Project_Schedule', 'Near Baseline'), ('City_Council_District', 'District 3'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.090707634678949'), ('Y', '42.334201045448793'), ('OBJECTID', '4'), ('Longitude', '-71.0907070348779'), ('Latitude', '42.3341923784647'), ('FID', '3'), ('OBJECTID_1', '10'), ('OBJECTID_12', '109'), ('ID', '69'), ('City_Department', 'Police Department'), ('Capital_Project_Number', 'CPD23970'), ('Capital_Asset_Name', 'Police Headquarters'), ('Capital_Project_Title', 'Police Headquarters Exterior Work'), ('ID1', '69'), ('Project_Description', 'Improve the plinth associated with the parking lot knee wall, strengthen weakened security elements, and address the deteriorating condition of the rotunda.'), ('Neighborhood', 'Roxbury'), ('Project_Status', 'In Design'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '655000'), ('Total_Project_Budget', '750000'), ('Project_Schedule', 'Near Baseline'), ('City_Council_District', 'District 7'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.098163340012476'), ('Y', '42.332235013836772'), ('OBJECTID', '5'), ('Longitude', '-71.0981627378814'), ('Latitude', '42.332226346718'), ('FID', '4'), ('OBJECTID_1', '15'), ('OBJECTID_12', '114'), ('ID', '79'), ('City_Department', 'Boston Center for Youth and Families'), ('Capital_Project_Number', 'CCC23931'), ('Capital_Asset_Name', 'Tobin Community Center'), ('Capital_Project_Title', 'BCYF Tobin Commnuity Center'), ('ID1', '79'), ('Project_Description', 'Implement recommendations from recent site study that will enhance the grounds of the Community Center including a new lawn and an outdoor stage that will create an inviting space to support outdoor youth and family events.'), ('Neighborhood', 'Mission Hill'), ('Project_Status', 'New Project'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '160000'), ('Total_Project_Budget', '950000'), ('Project_Schedule', 'Starting after FY17'), ('City_Council_District', 'District 9'), ('Investment_Categorization', 'Health & Human Services')])
# OrderedDict([('\ufeffX', '-71.098016860899108'), ('Y', '42.313876859349854'), ('OBJECTID', '6'), ('Longitude', '-71.0980162598255'), ('Latitude', '42.3138681964526'), ('FID', '5'), ('OBJECTID_1', '20'), ('OBJECTID_12', '5'), ('ID', '437'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS24549'), ('Capital_Asset_Name', 'Hernandez School'), ('Capital_Project_Title', 'Exterior Site Improvements at Hernandez School'), ('ID1', '437'), ('Project_Description', "General site improvements including permeable paving that will reduce the volume of storm water run-off entering the Boston Water and Sewer Commission's (BWSC) storm water system. The BWSC is funding a portion of this project."), ('Neighborhood', 'Roxbury'), ('Project_Status', 'New Project'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '150000'), ('Total_Project_Budget', '675000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 6'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.069564881673216'), ('Y', '42.281260289050003'), ('OBJECTID', '7'), ('Longitude', '-71.0695642921973'), ('Latitude', '42.2812516311534'), ('FID', '6'), ('OBJECTID_1', '26'), ('OBJECTID_12', '11'), ('ID', '443'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS24312'), ('Capital_Asset_Name', 'Henderson School at Wilson'), ('Capital_Project_Title', 'Access Improvements at Henderson Inclusion Upper School Phase II'), ('ID1', '443'), ('Project_Description', 'Accessibility renovations including bathroom and fire system upgrades.'), ('Neighborhood', 'Dorchester'), ('Project_Status', 'In Design'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '200000'), ('Total_Project_Budget', '4075000'), ('Project_Schedule', 'Near Baseline'), ('City_Council_District', 'District 4'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.034909946176057'), ('Y', '42.365552094188637'), ('OBJECTID', '8'), ('Longitude', '-71.0349093628185'), ('Latitude', '42.3655434189317'), ('FID', '7'), ('OBJECTID_1', '27'), ('OBJECTID_12', '12'), ('ID', '444'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS23855'), ('Capital_Asset_Name', 'Adams School'), ('Capital_Project_Title', 'Security Related Improvements at Various Schools'), ('ID1', '444'), ('Project_Description', 'Install intercom and clock systems, re-key doors, expand card access, replace smoke doors, install motion detectors and other security related improvements.'), ('Neighborhood', 'East Boston'), ('Project_Status', 'Annual Program'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '45455'), ('Total_Project_Budget', '6500000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 1'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.135369477060905'), ('Y', '42.277750945280594'), ('OBJECTID', '9'), ('Longitude', '-71.1353688658645'), ('Latitude', '42.2777422903004'), ('FID', '8'), ('OBJECTID_1', '31'), ('OBJECTID_12', '16'), ('ID', '448'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS23855'), ('Capital_Asset_Name', 'Bates School'), ('Capital_Project_Title', 'Security Related Improvements at Various Schools'), ('ID1', '448'), ('Project_Description', 'Install intercom and clock systems, re-key doors, expand card access, replace smoke doors, install motion detectors and other security related improvements.'), ('Neighborhood', 'Roslindale'), ('Project_Status', 'Annual Program'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '45455'), ('Total_Project_Budget', '6500000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 5'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.104577607345831'), ('Y', '42.267162438248199'), ('OBJECTID', '10'), ('Longitude', '-71.1045770072225'), ('Latitude', '42.2671537837351'), ('FID', '9'), ('OBJECTID_1', '36'), ('OBJECTID_12', '21'), ('ID', '453'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS23855'), ('Capital_Asset_Name', 'Chittick School'), ('Capital_Project_Title', 'Security Related Improvements at Various Schools'), ('ID1', '453'), ('Project_Description', 'Install intercom and clock systems, re-key doors, expand card access, replace smoke doors, install motion detectors and other security related improvements.'), ('Neighborhood', 'Mattapan'), ('Project_Status', 'Annual Program'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '45455'), ('Total_Project_Budget', '6500000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 5'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.114246728506444'), ('Y', '42.318711795750836'), ('OBJECTID', '11'), ('Longitude', '-71.1142461222655'), ('Latitude', '42.3187031316814'), ('FID', '10'), ('OBJECTID_1', '40'), ('OBJECTID_12', '25'), ('ID', '457'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS24332'), ('Capital_Asset_Name', 'Curley School'), ('Capital_Project_Title', 'Window Replacements at 7 Schools'), ('ID1', '457'), ('Project_Description', 'Complete a feasibility study and develop schematic designs for window replacement projects at Community Academy, Curley School, Ellis School, McKay K-8 School, Sumner School, TechBoston Academy, and Young Achievers K-8 School in partnership with the MSBA'), ('Neighborhood', 'Jamaica Plain'), ('Project_Status', 'In Design'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '467308'), ('Total_Project_Budget', '25743163'), ('Project_Schedule', 'Near Baseline'), ('City_Council_District', 'District 6'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.053329959252437'), ('Y', '42.366013792688818'), ('OBJECTID', '12'), ('Longitude', '-71.0533293697653'), ('Latitude', '42.3660051177137'), ('FID', '11'), ('OBJECTID_1', '43'), ('OBJECTID_12', '28'), ('ID', '460'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS24296'), ('Capital_Asset_Name', 'Eliot School'), ('Capital_Project_Title', 'Eliot School Access Improvements'), ('ID1', '460'), ('Project_Description', "New school entrance, accessible bathroom renovations, and sprinkler system at the Eliot School's Charter Street building."), ('Neighborhood', 'North End'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '0'), ('Total_Project_Budget', '450000'), ('Project_Schedule', 'Starting after FY17'), ('City_Council_District', 'District 1'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.093022633391868'), ('Y', '42.316149962941807'), ('OBJECTID', '13'), ('Longitude', '-71.0930220344512'), ('Latitude', '42.3161412989492'), ('FID', '12'), ('OBJECTID_1', '44'), ('OBJECTID_12', '29'), ('ID', '461'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS24332'), ('Capital_Asset_Name', 'Ellis School'), ('Capital_Project_Title', 'Window Replacements at 7 Schools'), ('ID1', '461'), ('Project_Description', 'Complete a feasibility study and develop schematic designs for window replacement projects at Community Academy, Curley School, Ellis School, McKay K-8 School, Sumner School, TechBoston Academy, and Young Achievers K-8 School in partnership with the MSBA'), ('Neighborhood', 'Roxbury'), ('Project_Status', 'In Design'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '467308'), ('Total_Project_Budget', '25743163'), ('Project_Schedule', 'Near Baseline'), ('City_Council_District', 'District 7'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.072952374230397'), ('Y', '42.323506584981914'), ('OBJECTID', '14'), ('Longitude', '-71.0729517809223'), ('Latitude', '42.3234979188725'), ('FID', '13'), ('OBJECTID_1', '45'), ('OBJECTID_12', '30'), ('ID', '462'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS23860'), ('Capital_Asset_Name', 'Dudley Street Neighborhood School'), ('Capital_Project_Title', 'Quality Improvement Fund for Schools'), ('ID1', '462'), ('Project_Description', 'Capital investment program targeting facility improvements at the Dudley Street Neighborhood School.'), ('Neighborhood', 'Roxbury'), ('Project_Status', 'In Construction'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '2274036'), ('Total_Project_Budget', '15000000'), ('Project_Schedule', 'Baseline Project'), ('City_Council_District', 'District 7'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.059815239347515'), ('Y', '42.313660419527885'), ('OBJECTID', '15'), ('Longitude', '-71.0598146506505'), ('Latitude', '42.3136517546839'), ('FID', '14'), ('OBJECTID_1', '47'), ('OBJECTID_12', '32'), ('ID', '464'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS23855'), ('Capital_Asset_Name', 'Everett, Edward'), ('Capital_Project_Title', 'Security Related Improvements at Various Schools'), ('ID1', '464'), ('Project_Description', 'Install intercom and clock systems, re-key doors, expand card access, replace smoke doors, install motion detectors and other security related improvements.'), ('Neighborhood', 'Mission Hill'), ('Project_Status', 'Annual Program'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '45455'), ('Total_Project_Budget', '6500000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 8'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.103462982399407'), ('Y', '42.308924926233765'), ('OBJECTID', '16'), ('Longitude', '-71.1034623800429'), ('Latitude', '42.3089162644469'), ('FID', '15'), ('OBJECTID_1', '50'), ('OBJECTID_12', '35'), ('ID', '467'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS23855'), ('Capital_Asset_Name', 'Margaret Fuller building'), ('Capital_Project_Title', 'Security Related Improvements at Various Schools'), ('ID1', '467'), ('Project_Description', 'Install intercom and clock systems, re-key doors, expand card access, replace smoke doors, install motion detectors and other security related improvements.'), ('Neighborhood', 'Jamaica Plain'), ('Project_Status', 'Annual Program'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '45455'), ('Total_Project_Budget', '6500000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 6'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.117778216563153'), ('Y', '42.265207792454255'), ('OBJECTID', '17'), ('Longitude', '-71.1177776121675'), ('Latitude', '42.2651991392583'), ('FID', '16'), ('OBJECTID_1', '53'), ('OBJECTID_12', '38'), ('ID', '470'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS24348'), ('Capital_Asset_Name', 'ACC at E Greenwood'), ('Capital_Project_Title', 'ACC at E. Greenwood'), ('ID1', '470'), ('Project_Description', 'Interior renovation of the E. Greenwood facility for Another Course to College.'), ('Neighborhood', 'Hyde Park'), ('Project_Status', 'In Design'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '3500000'), ('Total_Project_Budget', '7000000'), ('Project_Schedule', 'Near Baseline'), ('City_Council_District', 'District 5'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.080217547077211'), ('Y', '42.29695850969884'), ('OBJECTID', '18'), ('Longitude', '-71.0802169529818'), ('Latitude', '42.2969498494046'), ('FID', '17'), ('OBJECTID_1', '54'), ('OBJECTID_12', '39'), ('ID', '471'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS23855'), ('Capital_Asset_Name', 'Greenwood, Sarah'), ('Capital_Project_Title', 'Security Related Improvements at Various Schools'), ('ID1', '471'), ('Project_Description', 'Install intercom and clock systems, re-key doors, expand card access, replace smoke doors, install motion detectors and other security related improvements.'), ('Neighborhood', 'Dorchester'), ('Project_Status', 'Annual Program'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '45455'), ('Total_Project_Budget', '6500000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 4'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.075554325496611'), ('Y', '42.330617714251275'), ('OBJECTID', '19'), ('Longitude', '-71.07555373083'), ('Latitude', '42.3306090474037'), ('FID', '18'), ('OBJECTID_1', '63'), ('OBJECTID_12', '48'), ('ID', '480'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS23855'), ('Capital_Asset_Name', 'Orchard Gardens K-8 School'), ('Capital_Project_Title', 'Security Related Improvements at Various Schools'), ('ID1', '480'), ('Project_Description', 'Install intercom and clock systems, re-key doors, expand card access, replace smoke doors, install motion detectors and other security related improvements.'), ('Neighborhood', 'Roxbury'), ('Project_Status', 'Annual Program'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '45455'), ('Total_Project_Budget', '6500000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 7'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.077973986775277'), ('Y', '42.338967149761721'), ('OBJECTID', '20'), ('Longitude', '-71.0779733911419'), ('Latitude', '42.3389584813668'), ('FID', '19'), ('OBJECTID_1', '66'), ('OBJECTID_12', '51'), ('ID', '483'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS23855'), ('Capital_Asset_Name', 'Hurley School'), ('Capital_Project_Title', 'Security Related Improvements at Various Schools'), ('ID1', '483'), ('Project_Description', 'Install intercom and clock systems, re-key doors, expand card access, replace smoke doors, install motion detectors and other security related improvements.'), ('Neighborhood', 'South End'), ('Project_Status', 'Annual Program'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '45455'), ('Total_Project_Budget', '6500000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 7'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.105801005910578'), ('Y', '42.321746736598122'), ('OBJECTID', '21'), ('Longitude', '-71.1058004015439'), ('Latitude', '42.3217380720318'), ('FID', '20'), ('OBJECTID_1', '69'), ('OBJECTID_12', '54'), ('ID', '486'), ('City_Department', 'School Department'), ('Capital_Project_Number', 'CPS23855'), ('Capital_Asset_Name', 'J. F. Kennedy School'), ('Capital_Project_Title', 'Security Related Improvements at Various Schools'), ('ID1', '486'), ('Project_Description', 'Install intercom and clock systems, re-key doors, expand card access, replace smoke doors, install motion detectors and other security related improvements.'), ('Neighborhood', 'East Boston'), ('Project_Status', 'Annual Program'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '45455'), ('Total_Project_Budget', '6500000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 1'), ('Investment_Categorization', 'Education')])
# OrderedDict([('\ufeffX', '-71.037149489139622'), ('Y', '42.3349638113027'), ('OBJECTID', '22'), ('Longitude', '-71.0371489065294'), ('Latitude', '42.3349551416669'), ('FID', '21'), ('OBJECTID_1', '70'), ('OBJECTID_12', '55'), ('ID', '1'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 2 Ladder 19'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '1'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'South Boston'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 2'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.06854986573849'), ('Y', '42.339953982250144'), ('OBJECTID', '23'), ('Longitude', '-71.0685492726937'), ('Latitude', '42.3399453134738'), ('FID', '22'), ('OBJECTID_1', '71'), ('OBJECTID_12', '56'), ('ID', '2'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 3'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '2'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'South End'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 2'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.065675126007463'), ('Y', '42.360863068316164'), ('OBJECTID', '24'), ('Longitude', '-71.0656745326786'), ('Latitude', '42.3608543954495'), ('FID', '23'), ('OBJECTID_1', '72'), ('OBJECTID_12', '57'), ('ID', '3'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 4 Ladder 24'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '3'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'Beacon Hill'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 2'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.030195464410681'), ('Y', '42.379056820904637'), ('OBJECTID', '25'), ('Longitude', '-71.0301948815422'), ('Latitude', '42.3790481425012'), ('FID', '24'), ('OBJECTID_1', '73'), ('OBJECTID_12', '58'), ('ID', '4'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 5'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '4'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'East Boston'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 1'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.070986843059444'), ('Y', '42.348931830879067'), ('OBJECTID', '26'), ('Longitude', '-71.0709862491568'), ('Latitude', '42.3489231598273'), ('FID', '25'), ('OBJECTID_1', '74'), ('OBJECTID_12', '59'), ('ID', '5'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 7 Ladder 17'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '5'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'South End'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 2'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.053146150179117'), ('Y', '42.365792101652637'), ('OBJECTID', '27'), ('Longitude', '-71.0531455612001'), ('Latitude', '42.3657834269529'), ('FID', '26'), ('OBJECTID_1', '75'), ('OBJECTID_12', '60'), ('ID', '6'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 8 Ladder 1'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '6'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'North End'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 1'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.038722799573875'), ('Y', '42.368062663544123'), ('OBJECTID', '28'), ('Longitude', '-71.0387222148405'), ('Latitude', '42.3680539883479'), ('FID', '27'), ('OBJECTID_1', '76'), ('OBJECTID_12', '61'), ('ID', '7'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 9 Ladder 2'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '7'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'East Boston'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 1'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.082350849624774'), ('Y', '42.328840953696471'), ('OBJECTID', '29'), ('Longitude', '-71.0823502529636'), ('Latitude', '42.3288322869308'), ('FID', '28'), ('OBJECTID_1', '77'), ('OBJECTID_12', '62'), ('ID', '8'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 14 Ladder 4'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '8'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'Roxbury'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 7'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.078769081522069'), ('Y', '42.278294101191648'), ('OBJECTID', '30'), ('Longitude', '-71.0787684885187'), ('Latitude', '42.2782854441111'), ('FID', '29'), ('OBJECTID_1', '78'), ('OBJECTID_12', '63'), ('ID', '9'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 16'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '9'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'Mattapan'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 4'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.061601731591125'), ('Y', '42.307737203343905'), ('OBJECTID', '31'), ('Longitude', '-71.0616011429269'), ('Latitude', '42.3077285399808'), ('FID', '30'), ('OBJECTID_1', '79'), ('OBJECTID_12', '64'), ('ID', '10'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24125'), ('Capital_Asset_Name', 'Engine 17 Ladder 7'), ('Capital_Project_Title', 'Engine 17'), ('ID1', '10'), ('Project_Description', 'Design and construct a new fire station.'), ('Neighborhood', 'Dorchester'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '250000'), ('Total_Project_Budget', '13000000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 3'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.063848335100758'), ('Y', '42.286509790231818'), ('OBJECTID', '32'), ('Longitude', '-71.0638477474842'), ('Latitude', '42.2865011309955'), ('FID', '31'), ('OBJECTID_1', '80'), ('OBJECTID_12', '65'), ('ID', '11'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 18 Ladder 6'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '11'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'Dorchester'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 3'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.047814455959212'), ('Y', '42.288596252139925'), ('OBJECTID', '33'), ('Longitude', '-71.047813872764'), ('Latitude', '42.2885875917063'), ('FID', '32'), ('OBJECTID_1', '81'), ('OBJECTID_12', '66'), ('ID', '12'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 20'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '12'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'Dorchester'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 3'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.063209404731779'), ('Y', '42.318324042306955'), ('OBJECTID', '34'), ('Longitude', '-71.0632088146615'), ('Latitude', '42.3183153773629'), ('FID', '33'), ('OBJECTID_1', '82'), ('OBJECTID_12', '67'), ('ID', '13'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 21'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '13'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'Dorchester'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 3'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.077539148718202'), ('Y', '42.340443603056229'), ('OBJECTID', '35'), ('Longitude', '-71.077538553499'), ('Latitude', '42.3404349337252'), ('FID', '34'), ('OBJECTID_1', '83'), ('OBJECTID_12', '68'), ('ID', '14'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 22'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '14'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'South End'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 7'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.082238173350035'), ('Y', '42.307487336638033'), ('OBJECTID', '36'), ('Longitude', '-71.0822375782731'), ('Latitude', '42.3074786741387'), ('FID', '35'), ('OBJECTID_1', '84'), ('OBJECTID_12', '69'), ('ID', '15'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 24 Ladder 23'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '15'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'Roxbury'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 4'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.153420219758587'), ('Y', '42.342696726056978'), ('OBJECTID', '37'), ('Longitude', '-71.153419598744'), ('Latitude', '42.3426880593634'), ('FID', '36'), ('OBJECTID_1', '85'), ('OBJECTID_12', '70'), ('ID', '18'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24092'), ('Capital_Asset_Name', 'Engine 29 Ladder 11'), ('Capital_Project_Title', 'Building Envelope Repairs at Various Stations'), ('ID1', '18'), ('Project_Description', 'Building and envelope repairs at Engine 29, 32, 37, 53 and 56.'), ('Neighborhood', 'Allston/Brighton'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '46000'), ('Total_Project_Budget', '2017500'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 9'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.156539592370038'), ('Y', '42.284025944797769'), ('OBJECTID', '38'), ('Longitude', '-71.1565389739343'), ('Latitude', '42.2840172886395'), ('FID', '37'), ('OBJECTID_1', '86'), ('OBJECTID_12', '71'), ('ID', '19'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 30 Ladder 25'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '19'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'West Roxbury'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 6'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.071601336287628'), ('Y', '42.383826400488985'), ('OBJECTID', '39'), ('Longitude', '-71.0716007396783'), ('Latitude', '42.383817722966'), ('FID', '38'), ('OBJECTID_1', '87'), ('OBJECTID_12', '72'), ('ID', '20'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24092'), ('Capital_Asset_Name', 'Engine 32 Ladder 9'), ('Capital_Project_Title', 'Building Envelope Repairs at Various Stations'), ('ID1', '20'), ('Project_Description', 'Building and envelope repairs at Engine 29, 32, 37, 53 and 56.'), ('Neighborhood', 'Charlestown'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '46000'), ('Total_Project_Budget', '2017500'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 1'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.085554766795909'), ('Y', '42.348128171261024'), ('OBJECTID', '40'), ('Longitude', '-71.0855541676556'), ('Latitude', '42.3481195012007'), ('FID', '39'), ('OBJECTID_1', '88'), ('OBJECTID_12', '73'), ('ID', '21'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 33 Ladder 15'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '21'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'Back Bay'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 8'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.096056070609322'), ('Y', '42.337206946849413'), ('OBJECTID', '41'), ('Longitude', '-71.0960554686539'), ('Latitude', '42.337198278937'), ('FID', '40'), ('OBJECTID_1', '89'), ('OBJECTID_12', '74'), ('ID', '22'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24092'), ('Capital_Asset_Name', 'Engine 37 Ladder 26'), ('Capital_Project_Title', 'Building Envelope Repairs at Various Stations'), ('ID1', '22'), ('Project_Description', 'Building and envelope repairs at Engine 29, 32, 37, 53 and 56.'), ('Neighborhood', 'Roxbury'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '46000'), ('Total_Project_Budget', '2017500'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 7'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.050481765784824'), ('Y', '42.339587597756854'), ('OBJECTID', '42'), ('Longitude', '-71.0504811793839'), ('Latitude', '42.3395789283989'), ('FID', '41'), ('OBJECTID_1', '90'), ('OBJECTID_12', '75'), ('ID', '23'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 39 Ladder 18'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '23'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'South Boston'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 2'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.136104946721943'), ('Y', '42.353810471723797'), ('OBJECTID', '43'), ('Longitude', '-71.1361043307867'), ('Latitude', '42.3538018018642'), ('FID', '42'), ('OBJECTID_1', '91'), ('OBJECTID_12', '76'), ('ID', '24'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 41 Ladder 14'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '24'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'Allston/Brighton'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 9'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.097729613066278'), ('Y', '42.318383172216251'), ('OBJECTID', '44'), ('Longitude', '-71.0977290116901'), ('Latitude', '42.3183745084043'), ('FID', '43'), ('OBJECTID_1', '92'), ('OBJECTID_12', '77'), ('ID', '25'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24126'), ('Capital_Asset_Name', 'Engine 42'), ('Capital_Project_Title', 'Engine 42'), ('ID1', '25'), ('Project_Description', 'Design and construct a new fire station.'), ('Neighborhood', 'Roxbury'), ('Project_Status', 'In Design'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '790000'), ('Total_Project_Budget', '10000000'), ('Project_Schedule', 'Near Baseline'), ('City_Council_District', 'District 6'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.119882413668932'), ('Y', '42.255109894463494'), ('OBJECTID', '45'), ('Longitude', '-71.1198818093049'), ('Latitude', '42.2551012425213'), ('FID', '44'), ('OBJECTID_1', '93'), ('OBJECTID_12', '78'), ('ID', '26'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 48 Ladder 28'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '26'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'Hyde Park'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 5'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.131246483337804'), ('Y', '42.236820560615179'), ('OBJECTID', '46'), ('Longitude', '-71.1312458756183'), ('Latitude', '42.2368119132352'), ('FID', '45'), ('OBJECTID_1', '94'), ('OBJECTID_12', '79'), ('ID', '27'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 49'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '27'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'Hyde Park'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 5'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.061154560299613'), ('Y', '42.374237664001477'), ('OBJECTID', '47'), ('Longitude', '-71.0611539681733'), ('Latitude', '42.3742289882413'), ('FID', '46'), ('OBJECTID_1', '95'), ('OBJECTID_12', '80'), ('ID', '28'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD23280'), ('Capital_Asset_Name', 'Engine 50'), ('Capital_Project_Title', 'Engine 50'), ('ID1', '28'), ('Project_Description', 'Full building renovation including exterior masonry work, upgrades to building systems, and widening of apparatus doors.'), ('Neighborhood', 'Charlestown'), ('Project_Status', 'In Design'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '200000'), ('Total_Project_Budget', '3510000'), ('Project_Schedule', 'Near Baseline'), ('City_Council_District', 'District 1'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.168183149103953'), ('Y', '42.351268684212421'), ('OBJECTID', '48'), ('Longitude', '-71.1681825226573'), ('Latitude', '42.3512600164995'), ('FID', '47'), ('OBJECTID_1', '96'), ('OBJECTID_12', '81'), ('ID', '29'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 51'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '29'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'Allston/Brighton'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 9'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.089699873838086'), ('Y', '42.290896231242236'), ('OBJECTID', '49'), ('Longitude', '-71.0896992773128'), ('Latitude', '42.2908875719509'), ('FID', '48'), ('OBJECTID_1', '97'), ('OBJECTID_12', '82'), ('ID', '30'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 52 Ladder 29'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '30'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'Dorchester'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 4'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.117453243255142'), ('Y', '42.278994463090065'), ('OBJECTID', '50'), ('Longitude', '-71.1174526376825'), ('Latitude', '42.2789858068356'), ('FID', '49'), ('OBJECTID_1', '98'), ('OBJECTID_12', '83'), ('ID', '31'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24092'), ('Capital_Asset_Name', 'Engine 53 Ladder 16'), ('Capital_Project_Title', 'Building Envelope Repairs at Various Stations'), ('ID1', '31'), ('Project_Description', 'Building and envelope repairs at Engine 29, 32, 37, 53 and 56.'), ('Neighborhood', 'Roslindale'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '46000'), ('Total_Project_Budget', '2017500'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 5'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.154874391659703'), ('Y', '42.263964843031403'), ('OBJECTID', '51'), ('Longitude', '-71.1548737748228'), ('Latitude', '42.2639561906965'), ('FID', '50'), ('OBJECTID_1', '99'), ('OBJECTID_12', '84'), ('ID', '32'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Engine 55'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '32'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'West Roxbury'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 6'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.004191380372106'), ('Y', '42.387750437384518'), ('OBJECTID', '52'), ('Longitude', '-71.0041908063094'), ('Latitude', '42.3877417567399'), ('FID', '51'), ('OBJECTID_1', '100'), ('OBJECTID_12', '85'), ('ID', '33'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24092'), ('Capital_Asset_Name', 'Engine 56  Ladder 21'), ('Capital_Project_Title', 'Building Envelope Repairs at Various Stations'), ('ID1', '33'), ('Project_Description', 'Building and envelope repairs at Engine 29, 32, 37, 53 and 56.'), ('Neighborhood', 'East Boston'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '46000'), ('Total_Project_Budget', '2017500'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 1'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-70.990382513185565'), ('Y', '42.307287498525085'), ('OBJECTID', '53'), ('Longitude', '-70.9903819483977'), ('Latitude', '42.3072788333491'), ('FID', '52'), ('OBJECTID_1', '101'), ('OBJECTID_12', '87'), ('ID', '35'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD24102'), ('Capital_Asset_Name', 'Fire Academy'), ('Capital_Project_Title', 'Diesel Exhaust System Replacement'), ('ID1', '35'), ('Project_Description', 'Replace diesel exhaust systems at all locations.'), ('Neighborhood', 'Harbor Islands'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '10226'), ('Total_Project_Budget', '4517000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 3'), ('Investment_Categorization', 'Public Safety')])
# OrderedDict([('\ufeffX', '-71.091081513504179'), ('Y', '42.346298452736697'), ('OBJECTID', '54'), ('Longitude', '-71.0910809129026'), ('Latitude', '42.3462897827038'), ('FID', '53'), ('OBJECTID_1', '102'), ('OBJECTID_12', '88'), ('ID', '36'), ('City_Department', 'Fire Department'), ('Capital_Project_Number', 'CFD23144'), ('Capital_Asset_Name', 'Fire Alarm'), ('Capital_Project_Title', 'HVAC / Boiler Replacement at Various Stations'), ('ID1', '36'), ('Project_Description', 'Install / upgrade boilers, heating, and lighting systems.'), ('Neighborhood', 'Fenway/Kenmore'), ('Project_Status', 'In Construction'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '53057'), ('Total_Project_Budget', '3218861'), ('Project_Schedule', 'Baseline Project'), ('City_Council_District', 'District 8'), ('Investment_Categorization', 'Public Safety')])
# ...
# OrderedDict([('\ufeffX', '-71.118850212056884'), ('Y', '42.284918315173321'), ('OBJECTID', '211'), ('Longitude', '-71.1188496060807'), ('Latitude', '42.2849096575426'), ('FID', '210'), ('OBJECTID_1', '2798'), ('OBJECTID_12', '0'), ('ID', '1592'), ('City_Department', 'Parks and Recreation Department'), ('Capital_Project_Number', 'CPR24521'), ('Capital_Asset_Name', 'Mt. Hope Street Parcel'), ('Capital_Project_Title', 'Mt. Hope Street Parcel'), ('ID1', '1592'), ('Project_Description', 'Study and implement strategies that will transform the DND parcel into a park.'), ('Neighborhood', 'Roslindale'), ('Project_Status', 'New Project'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '50000'), ('Total_Project_Budget', '50000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 4'), ('Investment_Categorization', 'Environment, Energy & Open Space')])
# OrderedDict([('\ufeffX', '-71.128967567336915'), ('Y', '42.249723444146937'), ('OBJECTID', '212'), ('Longitude', '-71.1289669596272'), ('Latitude', '42.2497147940606'), ('FID', '211'), ('OBJECTID_1', '2800'), ('OBJECTID_12', '0'), ('ID', '1594'), ('City_Department', 'Parks and Recreation Department'), ('Capital_Project_Number', 'CPR24233'), ('Capital_Asset_Name', 'Reservation Road Park'), ('Capital_Project_Title', 'Reservation Road Park'), ('ID1', '1594'), ('Project_Description', 'Comprehensive park renovation to include skate park improvements, artificial turf replacement, site improvements, and landscaping.'), ('Neighborhood', 'Hyde Park'), ('Project_Status', 'To Be Scheduled'), ('Operating_Impact', '0'), ('FY17_Projected_Expenditure', '410000'), ('Total_Project_Budget', '3960000'), ('Project_Schedule', 'Initiating in FY17'), ('City_Council_District', 'District 5'), ('Investment_Categorization', 'Environment, Energy & Open Space')])
# OrderedDict([('\ufeffX', '-71.12412157959578'), ('Y', '42.264372083092454'), ('OBJECTID', '213'), ('Longitude', '-71.1241209725536'), ('Latitude', '42.2643634302807'), ('FID', '212'), ('OBJECTID_1', '2801'), ('OBJECTID_12', '0'), ('ID', '1595'), ('City_Department', 'Parks and Recreation Department'), ('Capital_Project_Number', 'CPR21491'), ('Capital_Asset_Name', 'Sherrin Street Woods'), ('Capital_Project_Title', 'Urban Wilds Renovations'), ('ID1', '1595'), ('Project_Description', 'Renovation of walls, walkways, and signage within urban wilds owned by Environment and Parks Department.'), ('Neighborhood', 'Hyde Park'), ('Project_Status', 'Annual Program'), ('Operating_Impact', '-1'), ('FY17_Projected_Expenditure', '75000'), ('Total_Project_Budget', '3269419'), ('Project_Schedule', 'Baseline Project'), ('City_Council_District', 'District 5'), ('Investment_Categorization', 'Environment, Energy & Open Space')])
# document
#   prefix alg <http://datamechanics.io/algorithm/>
#   prefix dat <http://datamechanics.io/data/>
#   prefix ont <http://datamechanics.io/ontology#>
#   prefix log <http://datamechanics.io/log/>
#   prefix bwod <https://boston.opendatasoft.com/explore/dataset/boston-neighborhoods/>
#   prefix hub <http://bostonopendata-boston.opendata.arcgis.com/datasets>
#   prefix tree <http://datamechanics.io/data>
#
#   agent(alg:jhs2018_rpm1995#getdata, [prov:type='prov:SoftwareAgent', ont:Extension="py"])
#   entity(hub: geojson, [prov:label="Hubway stations in Boston", prov:type="ont:DataResource", ont:Extension="geojson"])
#   activity(log:uuid74fc51a1-03ac-4374-a32f-eb209235f7a0, -, -)
#   wasAssociatedWith(log:uuid74fc51a1-03ac-4374-a32f-eb209235f7a0, alg:jhs2018_rpm1995#getdata, -)
#   used(log:uuid74fc51a1-03ac-4374-a32f-eb209235f7a0, hub: geojson, -, [prov:type="ont:Retrieval"])
#   entity(tree: geojson, [prov:label="Trees in Boston", prov:type="ont:DataResource", ont:Extension="geojson"])
#   activity(log:uuid18f9d286-6349-4009-bd0c-095306b5053c, -, -)
#   wasAssociatedWith(log:uuid18f9d286-6349-4009-bd0c-095306b5053c, alg:jhs2018_rpm1995#getdata, -)
#   used(log:uuid18f9d286-6349-4009-bd0c-095306b5053c, tree: geojson, -, [prov:type="ont:Retrieval"])
#   entity(hub: json, [prov:label="Charging Stations in Boston", prov:type="ont:DataResource", ont:Extension="json"])
#   activity(log:uuid14f30225-6248-4d7c-812b-67ab2e5576d2, -, -)
#   wasAssociatedWith(log:uuid14f30225-6248-4d7c-812b-67ab2e5576d2, alg:jhs2018_rpm1995#getdata, -)
#   used(log:uuid14f30225-6248-4d7c-812b-67ab2e5576d2, hub: json, -, [prov:type="ont:Retrieval"])
#   entity(hub: geojson, [prov:label="Budget Facilities in Boston", prov:type="ont:DataResource", ont:Extension="geojson"])
#   activity(log:uuida51b9e9e-1cf0-4a53-808d-f6125bad36d9, -, -)
#   wasAssociatedWith(log:uuida51b9e9e-1cf0-4a53-808d-f6125bad36d9, alg:jhs2018_rpm1995#getdata, -)
#   used(log:uuida51b9e9e-1cf0-4a53-808d-f6125bad36d9, hub: geojson, -, [prov:type="ont:Retrieval"])
#   entity(hub: geojson, [prov:label="Open Spaces in Boston", prov:type="ont:DataResource", ont:Extension="geojson"])
#   activity(log:uuid50acfdc6-864c-4b26-af04-c7946d3422b3, -, -)
#   wasAssociatedWith(log:uuid50acfdc6-864c-4b26-af04-c7946d3422b3, alg:jhs2018_rpm1995#getdata, -)
#   used(log:uuid50acfdc6-864c-4b26-af04-c7946d3422b3, hub: geojson, -, [prov:type="ont:Retrieval"])
#   entity(dat:jhs2018_rpm1995hubway, [prov:label="hubway", prov:type="ont:DataSet"])
#   wasAttributedTo(dat:jhs2018_rpm1995hubway, alg:jhs2018_rpm1995#getdata)
#   wasGeneratedBy(dat:jhs2018_rpm1995hubway, log:uuid74fc51a1-03ac-4374-a32f-eb209235f7a0, -)
#   wasDerivedFrom(dat:jhs2018_rpm1995hubway, hub: geojson, log:uuid74fc51a1-03ac-4374-a32f-eb209235f7a0, log:uuid74fc51a1-03ac-4374-a32f-eb209235f7a0, log:uuid74fc51a1-03ac-4374-a32f-eb209235f7a0)
#   entity(dat:jhs2018_rpm1995trees, [prov:label="trees", prov:type="ont:DataSet"])
#   wasAttributedTo(dat:jhs2018_rpm1995trees, alg:jhs2018_rpm1995#getdata)
#   wasGeneratedBy(dat:jhs2018_rpm1995trees, log:uuid18f9d286-6349-4009-bd0c-095306b5053c, -)
#   wasDerivedFrom(dat:jhs2018_rpm1995trees, tree: geojson, log:uuid18f9d286-6349-4009-bd0c-095306b5053c, log:uuid18f9d286-6349-4009-bd0c-095306b5053c, log:uuid18f9d286-6349-4009-bd0c-095306b5053c)
#   entity(dat:jhs2018_rpm1995charge, [prov:label="charge", prov:type="ont:DataSet"])
#   wasAttributedTo(dat:jhs2018_rpm1995charge, alg:jhs2018_rpm1995#getdata)
#   wasGeneratedBy(dat:jhs2018_rpm1995charge, log:uuid14f30225-6248-4d7c-812b-67ab2e5576d2, -)
#   wasDerivedFrom(dat:jhs2018_rpm1995charge, hub: json, log:uuid14f30225-6248-4d7c-812b-67ab2e5576d2, log:uuid14f30225-6248-4d7c-812b-67ab2e5576d2, log:uuid14f30225-6248-4d7c-812b-67ab2e5576d2)
#   entity(dat:jhs2018_rpm1995budget, [prov:label="budget", prov:type="ont:DataSet"])
#   wasAttributedTo(dat:jhs2018_rpm1995budget, alg:jhs2018_rpm1995#getdata)
#   wasGeneratedBy(dat:jhs2018_rpm1995budget, log:uuida51b9e9e-1cf0-4a53-808d-f6125bad36d9, -)
#   wasDerivedFrom(dat:jhs2018_rpm1995budget, hub: geojson, log:uuida51b9e9e-1cf0-4a53-808d-f6125bad36d9, log:uuida51b9e9e-1cf0-4a53-808d-f6125bad36d9, log:uuida51b9e9e-1cf0-4a53-808d-f6125bad36d9)
#   entity(dat:jhs2018_rpm1995openspaces, [prov:label="openspaces", prov:type="ont:DataSet"])
#   wasAttributedTo(dat:jhs2018_rpm1995openspaces, alg:jhs2018_rpm1995#getdata)
#   wasGeneratedBy(dat:jhs2018_rpm1995openspaces, log:uuid50acfdc6-864c-4b26-af04-c7946d3422b3, -)
#   wasDerivedFrom(dat:jhs2018_rpm1995openspaces, hub: geojson, log:uuid50acfdc6-864c-4b26-af04-c7946d3422b3, log:uuid50acfdc6-864c-4b26-af04-c7946d3422b3, log:uuid50acfdc6-864c-4b26-af04-c7946d3422b3)
# endDocument
# {
#     "prefix": {
#         "alg": "http://datamechanics.io/algorithm/",
#         "dat": "http://datamechanics.io/data/",
#         "ont": "http://datamechanics.io/ontology#",
#         "log": "http://datamechanics.io/log/",
#         "bwod": "https://boston.opendatasoft.com/explore/dataset/boston-neighborhoods/",
#         "hub": "http://bostonopendata-boston.opendata.arcgis.com/datasets",
#         "tree": "http://datamechanics.io/data"
#     },
#     "agent": {
#         "alg:jhs2018_rpm1995#getdata": {
#             "prov:type": {
#                 "$": "prov:SoftwareAgent",
#                 "type": "prov:QUALIFIED_NAME"
#             },
#             "ont:Extension": "py"
#         }
#     },
#     "entity": {
#         "hub: geojson": [
#             {
#                 "prov:label": "Hubway stations in Boston",
#                 "prov:type": "ont:DataResource",
#                 "ont:Extension": "geojson"
#             },
#             {
#                 "prov:label": "Budget Facilities in Boston",
#                 "prov:type": "ont:DataResource",
#                 "ont:Extension": "geojson"
#             },
#             {
#                 "prov:label": "Open Spaces in Boston",
#                 "prov:type": "ont:DataResource",
#                 "ont:Extension": "geojson"
#             }
#         ],
#         "tree: geojson": {
#             "prov:label": "Trees in Boston",
#             "prov:type": "ont:DataResource",
#             "ont:Extension": "geojson"
#         },
#         "hub: json": {
#             "prov:label": "Charging Stations in Boston",
#             "prov:type": "ont:DataResource",
#             "ont:Extension": "json"
#         },
#         "dat:jhs2018_rpm1995hubway": {
#             "prov:label": "hubway",
#             "prov:type": "ont:DataSet"
#         },
#         "dat:jhs2018_rpm1995trees": {
#             "prov:label": "trees",
#             "prov:type": "ont:DataSet"
#         },
#         "dat:jhs2018_rpm1995charge": {
#             "prov:label": "charge",
#             "prov:type": "ont:DataSet"
#         },
#         "dat:jhs2018_rpm1995budget": {
#             "prov:label": "budget",
#             "prov:type": "ont:DataSet"
#         },
#         "dat:jhs2018_rpm1995openspaces": {
#             "prov:label": "openspaces",
#             "prov:type": "ont:DataSet"
#         }
#     },
#     "activity": {
#         "log:uuid74fc51a1-03ac-4374-a32f-eb209235f7a0": {},
#         "log:uuid18f9d286-6349-4009-bd0c-095306b5053c": {},
#         "log:uuid14f30225-6248-4d7c-812b-67ab2e5576d2": {},
#         "log:uuida51b9e9e-1cf0-4a53-808d-f6125bad36d9": {},
#         "log:uuid50acfdc6-864c-4b26-af04-c7946d3422b3": {}
#     },
#     "wasAssociatedWith": {
#         "_:id1": {
#             "prov:activity": "log:uuid74fc51a1-03ac-4374-a32f-eb209235f7a0",
#             "prov:agent": "alg:jhs2018_rpm1995#getdata"
#         },
#         "_:id3": {
#             "prov:activity": "log:uuid18f9d286-6349-4009-bd0c-095306b5053c",
#             "prov:agent": "alg:jhs2018_rpm1995#getdata"
#         },
#         "_:id5": {
#             "prov:activity": "log:uuid14f30225-6248-4d7c-812b-67ab2e5576d2",
#             "prov:agent": "alg:jhs2018_rpm1995#getdata"
#         },
#         "_:id7": {
#             "prov:activity": "log:uuida51b9e9e-1cf0-4a53-808d-f6125bad36d9",
#             "prov:agent": "alg:jhs2018_rpm1995#getdata"
#         },
#         "_:id9": {
#             "prov:activity": "log:uuid50acfdc6-864c-4b26-af04-c7946d3422b3",
#             "prov:agent": "alg:jhs2018_rpm1995#getdata"
#         }
#     },
#     "used": {
#         "_:id2": {
#             "prov:activity": "log:uuid74fc51a1-03ac-4374-a32f-eb209235f7a0",
#             "prov:entity": "hub: geojson",
#             "prov:type": "ont:Retrieval"
#         },
#         "_:id4": {
#             "prov:activity": "log:uuid18f9d286-6349-4009-bd0c-095306b5053c",
#             "prov:entity": "tree: geojson",
#             "prov:type": "ont:Retrieval"
#         },
#         "_:id6": {
#             "prov:activity": "log:uuid14f30225-6248-4d7c-812b-67ab2e5576d2",
#             "prov:entity": "hub: json",
#             "prov:type": "ont:Retrieval"
#         },
#         "_:id8": {
#             "prov:activity": "log:uuida51b9e9e-1cf0-4a53-808d-f6125bad36d9",
#             "prov:entity": "hub: geojson",
#             "prov:type": "ont:Retrieval"
#         },
#         "_:id10": {
#             "prov:activity": "log:uuid50acfdc6-864c-4b26-af04-c7946d3422b3",
#             "prov:entity": "hub: geojson",
#             "prov:type": "ont:Retrieval"
#         }
#     },
#     "wasAttributedTo": {
#         "_:id11": {
#             "prov:entity": "dat:jhs2018_rpm1995hubway",
#             "prov:agent": "alg:jhs2018_rpm1995#getdata"
#         },
#         "_:id14": {
#             "prov:entity": "dat:jhs2018_rpm1995trees",
#             "prov:agent": "alg:jhs2018_rpm1995#getdata"
#         },
#         "_:id17": {
#             "prov:entity": "dat:jhs2018_rpm1995charge",
#             "prov:agent": "alg:jhs2018_rpm1995#getdata"
#         },
#         "_:id20": {
#             "prov:entity": "dat:jhs2018_rpm1995budget",
#             "prov:agent": "alg:jhs2018_rpm1995#getdata"
#         },
#         "_:id23": {
#             "prov:entity": "dat:jhs2018_rpm1995openspaces",
#             "prov:agent": "alg:jhs2018_rpm1995#getdata"
#         }
#     },
#     "wasGeneratedBy": {
#         "_:id12": {
#             "prov:entity": "dat:jhs2018_rpm1995hubway",
#             "prov:activity": "log:uuid74fc51a1-03ac-4374-a32f-eb209235f7a0"
#         },
#         "_:id15": {
#             "prov:entity": "dat:jhs2018_rpm1995trees",
#             "prov:activity": "log:uuid18f9d286-6349-4009-bd0c-095306b5053c"
#         },
#         "_:id18": {
#             "prov:entity": "dat:jhs2018_rpm1995charge",
#             "prov:activity": "log:uuid14f30225-6248-4d7c-812b-67ab2e5576d2"
#         },
#         "_:id21": {
#             "prov:entity": "dat:jhs2018_rpm1995budget",
#             "prov:activity": "log:uuida51b9e9e-1cf0-4a53-808d-f6125bad36d9"
#         },
#         "_:id24": {
#             "prov:entity": "dat:jhs2018_rpm1995openspaces",
#             "prov:activity": "log:uuid50acfdc6-864c-4b26-af04-c7946d3422b3"
#         }
#     },
#     "wasDerivedFrom": {
#         "_:id13": {
#             "prov:generatedEntity": "dat:jhs2018_rpm1995hubway",
#             "prov:usedEntity": "hub: geojson",
#             "prov:activity": "log:uuid74fc51a1-03ac-4374-a32f-eb209235f7a0",
#             "prov:generation": "log:uuid74fc51a1-03ac-4374-a32f-eb209235f7a0",
#             "prov:usage": "log:uuid74fc51a1-03ac-4374-a32f-eb209235f7a0"
#         },
#         "_:id16": {
#             "prov:generatedEntity": "dat:jhs2018_rpm1995trees",
#             "prov:usedEntity": "tree: geojson",
#             "prov:activity": "log:uuid18f9d286-6349-4009-bd0c-095306b5053c",
#             "prov:generation": "log:uuid18f9d286-6349-4009-bd0c-095306b5053c",
#             "prov:usage": "log:uuid18f9d286-6349-4009-bd0c-095306b5053c"
#         },
#         "_:id19": {
#             "prov:generatedEntity": "dat:jhs2018_rpm1995charge",
#             "prov:usedEntity": "hub: json",
#             "prov:activity": "log:uuid14f30225-6248-4d7c-812b-67ab2e5576d2",
#             "prov:generation": "log:uuid14f30225-6248-4d7c-812b-67ab2e5576d2",
#             "prov:usage": "log:uuid14f30225-6248-4d7c-812b-67ab2e5576d2"
#         },
#         "_:id22": {
#             "prov:generatedEntity": "dat:jhs2018_rpm1995budget",
#             "prov:usedEntity": "hub: geojson",
#             "prov:activity": "log:uuida51b9e9e-1cf0-4a53-808d-f6125bad36d9",
#             "prov:generation": "log:uuida51b9e9e-1cf0-4a53-808d-f6125bad36d9",
#             "prov:usage": "log:uuida51b9e9e-1cf0-4a53-808d-f6125bad36d9"
#         },
#         "_:id25": {
#             "prov:generatedEntity": "dat:jhs2018_rpm1995openspaces",
#             "prov:usedEntity": "hub: geojson",
#             "prov:activity": "log:uuid50acfdc6-864c-4b26-af04-c7946d3422b3",
#             "prov:generation": "log:uuid50acfdc6-864c-4b26-af04-c7946d3422b3",
#             "prov:usage": "log:uuid50acfdc6-864c-4b26-af04-c7946d3422b3"
#         }
#     }
# }
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:91: DeprecationWarning: Database.logout() is deprecated
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:189: DeprecationWarning: Database.logout() is deprecated

# %%
# ############################## Projecting Coordinates and leaving out the boring data ################################

import dml
import prov.model
import datetime
import json
import uuid


class project_coordinates(dml.Algorithm):
    contributor = 'jhs2018_rpm1995'
    reads = ['jhs2018_rpm1995.hubway',                  # We will combine 3 datasets into dataset greenobjects, which
#              'jhs2018_rpm1995.trees',                   # will have just the type of objects (tree, charging station, etc.) and
             'jhs2018_rpm1995.charge',                  # its geographical coordinates
             'jhs2018_rpm1995.budget']
    writes = ['jhs2018_rpm1995.greenobjects']

    @staticmethod
    def extract(cursor, type, megalist):        # This function extracts the type of object we are looking at (eg: tree)
                                                # and its coordinates, and adds them to the list that we will write
        for elements in cursor:                 # into dataset "greenobjects"
            megalist.append({"Type": type, "Location": elements['geometry']['coordinates']})
        return megalist

    @staticmethod
    def execute(trial=False):
        # Retrieve datasets
        startTime = datetime.datetime.now()

        # Set up the database connection.
        client = dml.pymongo.MongoClient()
        repo = client.repo
        repo.authenticate('jhs2018_rpm1995', 'jhs2018_rpm1995')

        print("Now running project_coordinates.py")

        objects = []

        hubway = repo.jhs2018_rpm1995.hubway.find()
#         trees = repo.jhs2018_rpm1995.trees.find()
        charge = repo.jhs2018_rpm1995.charge.find()
        # openspaces = repo.jhs2018_rpm1995.openspaces.find()
        budget = repo.jhs2018_rpm1995.budget.find()

        objects = project_coordinates.extract(hubway, "hubway", objects)
#         objects = project_coordinates.extract(trees, "tree", objects)
        objects = project_coordinates.extract(charge, "charge", objects)

        for items in budget:
            if items['City_Department'] == "School Department":
                objects.append({"Type": "budget", "Location": [float(items['Longitude']), float(items['Latitude'])], "Budget": items['Total_Project_Budget']})
        repo.dropCollection("greenobjects")
        repo.createCollection("greenobjects")
        repo['jhs2018_rpm1995.greenobjects'].insert_many(objects)

        repo.logout()

        endTime = datetime.datetime.now()

        return {"start": startTime, "end": endTime}

    @staticmethod
    def provenance(doc=prov.model.ProvDocument(), startTime=None, endTime=None):

            # Create the provenance document describing everything happening
            # in this script. Each run of the script will generate a new
            # document describing that invocation event.

        client = dml.pymongo.MongoClient()
        repo = client.repo
        repo.authenticate('jhs2018_rpm1995', 'jhs2018_rpm1995')
        doc.add_namespace('alg', 'http://datamechanics.io/algorithm/')  # The scripts are in <folder>#<filename> format.
        doc.add_namespace('dat', 'http://datamechanics.io/data/')  # The data sets are in <user>#<collection> format.
        doc.add_namespace('ont', 'http://datamechanics.io/ontology#')  # 'Extension', 'DataResource', 'DataSet',
        # 'Retrieval', 'Query', or 'Computation'.
        doc.add_namespace('log', 'http://datamechanics.io/log/')  # The event log.
        doc.add_namespace('bwod', 'https://boston.opendatasoft.com/explore/dataset/boston-neighborhoods/')  # Boston
        # Wicked Open Data
        doc.add_namespace('ab', 'https://data.boston.gov/dataset/boston-neighborhoods')   # Analyze Boston

        this_script = doc.agent('alg:jhs2018_rpm1995#project_coordinates',
                                {prov.model.PROV_TYPE: prov.model.PROV['SoftwareAgent'], 'ont:Extension': 'py'})

# #######
        resource_hubway = doc.entity('bwod: hubstations', {'prov:label': 'Boston Hubway Stations',
                                                           prov.model.PROV_TYPE: 'ont:DataResource', 'ont:Extension':
                                                           'geojson'})

        resource_trees = doc.entity('alg: trees', {'prov:label': 'Trees in Boston', prov.model.PROV_TYPE:
                                                   'ont:DataResource', 'ont:Extension': 'json'})

        resource_charges = doc.entity('bwod: charging', {'prov:label': 'Charging Stations in Boston',
                                                         prov.model.PROV_TYPE: 'ont:DataResource', 'ont:Extension':
                                                         'json'})

        get_greenobjects = doc.activity('log:uuid' + str(uuid.uuid4()), startTime, endTime,
                                          {
                                                    prov.model.PROV_LABEL: "Locations of Hubway, Charging Stations "
                                                                           "and Trees in Boston",
                                                    prov.model.PROV_TYPE: 'ont:Computation'})

        doc.wasAssociatedWith(get_greenobjects, this_script)

        doc.usage(get_greenobjects, resource_hubway, startTime)
        doc.usage(get_greenobjects, resource_charges, startTime)
        doc.usage(get_greenobjects, resource_trees, startTime)

# #######
        greenobjects = doc.entity('dat:jhs2018_rpm1995_greenobjects',
                                  {prov.model.PROV_LABEL: 'Coordinates of Environment Friendly Assets in Boston',
                                   prov.model.PROV_TYPE: 'ont:DataSet'})
        doc.wasAttributedTo(greenobjects, this_script)
        doc.wasGeneratedBy(greenobjects, get_greenobjects, endTime)
        doc.wasDerivedFrom(greenobjects, resource_hubway, get_greenobjects, get_greenobjects,
                           get_greenobjects)
        doc.wasDerivedFrom(greenobjects, resource_trees, get_greenobjects, get_greenobjects,
                           get_greenobjects)
        doc.wasDerivedFrom(greenobjects, resource_charges, get_greenobjects, get_greenobjects,
                           get_greenobjects)

        repo.logout()

        return doc


project_coordinates.execute()
doc = project_coordinates.provenance()
print(doc.get_provn())
print(json.dumps(json.loads(doc.serialize()), indent=4))

# eof
# Out:
# Now running project_coordinates.py
# document
#   prefix alg <http://datamechanics.io/algorithm/>
#   prefix dat <http://datamechanics.io/data/>
#   prefix ont <http://datamechanics.io/ontology#>
#   prefix log <http://datamechanics.io/log/>
#   prefix bwod <https://boston.opendatasoft.com/explore/dataset/boston-neighborhoods/>
#   prefix ab <https://data.boston.gov/dataset/boston-neighborhoods>
#
#   agent(alg:jhs2018_rpm1995#project_coordinates, [prov:type='prov:SoftwareAgent', ont:Extension="py"])
#   entity(bwod: hubstations, [prov:label="Boston Hubway Stations", prov:type="ont:DataResource", ont:Extension="geojson"])
#   entity(alg: trees, [prov:label="Trees in Boston", prov:type="ont:DataResource", ont:Extension="json"])
#   entity(bwod: charging, [prov:label="Charging Stations in Boston", prov:type="ont:DataResource", ont:Extension="json"])
#   activity(log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634, -, -, [prov:label="Locations of Hubway, Charging Stations and Trees in Boston", prov:type="ont:Computation"])
#   wasAssociatedWith(log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634, alg:jhs2018_rpm1995#project_coordinates, -)
#   used(log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634, bwod: hubstations, -)
#   used(log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634, bwod: charging, -)
#   used(log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634, alg: trees, -)
#   entity(dat:jhs2018_rpm1995_greenobjects, [prov:label="Coordinates of Environment Friendly Assets in Boston", prov:type="ont:DataSet"])
#   wasAttributedTo(dat:jhs2018_rpm1995_greenobjects, alg:jhs2018_rpm1995#project_coordinates)
#   wasGeneratedBy(dat:jhs2018_rpm1995_greenobjects, log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634, -)
#   wasDerivedFrom(dat:jhs2018_rpm1995_greenobjects, bwod: hubstations, log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634, log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634, log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634)
#   wasDerivedFrom(dat:jhs2018_rpm1995_greenobjects, alg: trees, log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634, log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634, log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634)
#   wasDerivedFrom(dat:jhs2018_rpm1995_greenobjects, bwod: charging, log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634, log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634, log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634)
# endDocument
# {
#     "prefix": {
#         "alg": "http://datamechanics.io/algorithm/",
#         "dat": "http://datamechanics.io/data/",
#         "ont": "http://datamechanics.io/ontology#",
#         "log": "http://datamechanics.io/log/",
#         "bwod": "https://boston.opendatasoft.com/explore/dataset/boston-neighborhoods/",
#         "ab": "https://data.boston.gov/dataset/boston-neighborhoods"
#     },
#     "agent": {
#         "alg:jhs2018_rpm1995#project_coordinates": {
#             "prov:type": {
#                 "$": "prov:SoftwareAgent",
#                 "type": "prov:QUALIFIED_NAME"
#             },
#             "ont:Extension": "py"
#         }
#     },
#     "entity": {
#         "bwod: hubstations": {
#             "prov:label": "Boston Hubway Stations",
#             "prov:type": "ont:DataResource",
#             "ont:Extension": "geojson"
#         },
#         "alg: trees": {
#             "prov:label": "Trees in Boston",
#             "prov:type": "ont:DataResource",
#             "ont:Extension": "json"
#         },
#         "bwod: charging": {
#             "prov:label": "Charging Stations in Boston",
#             "prov:type": "ont:DataResource",
#             "ont:Extension": "json"
#         },
#         "dat:jhs2018_rpm1995_greenobjects": {
#             "prov:label": "Coordinates of Environment Friendly Assets in Boston",
#             "prov:type": "ont:DataSet"
#         }
#     },
#     "activity": {
#         "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634": {
#             "prov:label": "Locations of Hubway, Charging Stations and Trees in Boston",
#             "prov:type": "ont:Computation"
#         }
#     },
#     "wasAssociatedWith": {
#         "_:id1": {
#             "prov:activity": "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634",
#             "prov:agent": "alg:jhs2018_rpm1995#project_coordinates"
#         }
#     },
#     "used": {
#         "_:id2": {
#             "prov:activity": "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634",
#             "prov:entity": "bwod: hubstations"
#         },
#         "_:id3": {
#             "prov:activity": "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634",
#             "prov:entity": "bwod: charging"
#         },
#         "_:id4": {
#             "prov:activity": "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634",
#             "prov:entity": "alg: trees"
#         }
#     },
#     "wasAttributedTo": {
#         "_:id5": {
#             "prov:entity": "dat:jhs2018_rpm1995_greenobjects",
#             "prov:agent": "alg:jhs2018_rpm1995#project_coordinates"
#         }
#     },
#     "wasGeneratedBy": {
#         "_:id6": {
#             "prov:entity": "dat:jhs2018_rpm1995_greenobjects",
#             "prov:activity": "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634"
#         }
#     },
#     "wasDerivedFrom": {
#         "_:id7": {
#             "prov:generatedEntity": "dat:jhs2018_rpm1995_greenobjects",
#             "prov:usedEntity": "bwod: hubstations",
#             "prov:activity": "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634",
#             "prov:generation": "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634",
#             "prov:usage": "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634"
#         },
#         "_:id8": {
#             "prov:generatedEntity": "dat:jhs2018_rpm1995_greenobjects",
#             "prov:usedEntity": "alg: trees",
#             "prov:activity": "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634",
#             "prov:generation": "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634",
#             "prov:usage": "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634"
#         },
#         "_:id9": {
#             "prov:generatedEntity": "dat:jhs2018_rpm1995_greenobjects",
#             "prov:usedEntity": "bwod: charging",
#             "prov:activity": "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634",
#             "prov:generation": "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634",
#             "prov:usage": "log:uuidb1719a85-9cf1-4b38-a633-ca3141c84634"
#         }
#     }
# }
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:56: DeprecationWarning: Database.logout() is deprecated
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:121: DeprecationWarning: Database.logout() is deprecated

# %%
import dml
import prov.model
import datetime
import json
import uuid
import folium
import os
from math import cos, asin, sqrt


class display(dml.Algorithm):
    contributor = 'jhs2018_rpm1995'
    reads = ['jhs2018_rpm1995.greenassets']
    writes = ['jhs2018_rpm1995.kmeansdata']

    @staticmethod
    def findcell(value, axis):
        # return min(axis, key=lambda x: abs(x - value))    # Wrong logic... Spent an entire night on this line
        for i in range(1, len(axis)):
            if axis[i] > value:
                return axis[i-1]
            
    @staticmethod
    def distance(lat1, lon1, lat2, lon2):
        p = 0.017453292519943295
        a = 0.5 - cos((lat2-lat1)*p)/2 + cos(lat1*p)*cos(lat2*p) * (1-cos((lon2-lon1)*p)) / 2
        return 12742 * asin(sqrt(a))
    
    @staticmethod
    def closestpoint(cells, long, lat):     # Will never be able to recreate this again
        return min(cells, key=lambda x: display.distance(lat, long, x[0][1], x[0][0]))
        
    @staticmethod
    def execute(trial=False):
        # Retrieve datasets
        startTime = datetime.datetime.now()

        # Set up the database connection.
        client = dml.pymongo.MongoClient()
        repo = client.repo
        repo.authenticate('jhs2018_rpm1995', 'jhs2018_rpm1995')

        print("Now running display.py")

#         dir_path = os.path.dirname(os.path.abspath(__file__))
        dir_path = "C://Users//H//Desktop//course-2018-spr-proj//jhs2018_rpm1995"
        filenamemap = os.path.join(dir_path, "assets.html")
        map_osm = folium.Map(location=[39, -98.1], zoom_start=4)

        assets = repo.jhs2018_rpm1995.greenassets.find()
        budgets = repo.jhs2018_rpm1995.greenobjects.find({"Type": {"$eq": "budget"}})

        # for asset in assets:                                  # Uncomment these four lines to see assets on the map
        #     coords = (asset['Location'][1], asset['Location'][0])
        #     folium.Marker(coords, popup=str(coords)).add_to(map_osm)
        # map_osm.save(filenamemap)

        grid = {}       # This will contain coordinates of the grid as keys, and assets assigned to that grid as values
        cells = []      # To hold just the coordinates of the grid
        megalist = []   # Will hold data to write to database

        i = -71.189
        while i < -70.878:
            j = 42.234
            while j < 42.406:
                coords = (j, i)
                # folium.Marker(coords, popup=str(coords)).add_to(map_osm)      # Uncomment to see grid on map
                # grid[coords] = 0                                              # For overall counts
                grid[coords] = [[0], [0], [0], [0], [0]]                     # [[charge], [hubway], [open spaces], [trees], [budget]]
                cells.append(coords)
                j += 0.01
            i += 0.01
        # map_osm.save(filenamemap)                                             #

        xaxis = []                                                              # Adjust scale of grid here
        i = -71.189
        while i < -70.878:
            xaxis.append(i)
            i += 0.01

        yaxis = []                                                              # Adjust scale of grid here
        i = 42.234
        while i < 42.406:
            yaxis.append(i)
            i += 0.01
            
        budget_coords = []                      # To store coordinates of budgets
        for budget in budgets:
            budget_coords.append([budget['Location'], budget['Budget']])

#         for coords in budget_coords:
#             print("For coords: " + str(coords))
#             cell = display.closestcell(cells, coords[0], coords[1])
#             folium.Marker(cell, icon=folium.Icon(color='green')).add_to(map_osm)
            
        for cell in cells:
            answer = display.closestpoint(budget_coords, cell[1], cell[0])   # Hallelujah
            grid[cell][4][0] += float(answer[1])                              # Storing budget
        
        for asset in assets:                    # This loop finds the cell that the asset belongs to and correspondingly
            y = asset['Location'][1]            # ...increases the count of that asset type in the dictionary
            x = asset['Location'][0]            # ...representation
            typekind = asset['Type']
            ycell = display.findcell(y, yaxis)
            xcell = display.findcell(x, xaxis)
            if (ycell, xcell) in grid:      # O(1) lookup time. Hire me, Google
                # grid[(ycell, xcell)] += 1     # for overall counts
                if typekind == "charge":
                    grid[(ycell, xcell)][0][0] += 1
                elif typekind == "hubway":
                    grid[(ycell, xcell)][1][0] += 1
                elif typekind == "openspace":
                    grid[(ycell, xcell)][2][0] += 1
                elif typekind == "tree":
                    grid[(ycell, xcell)][3][0] += 1

        for coords, counts in grid.items():     # Gonna save to database and display on map
            megalist.append({"coordinates": coords, "charge_count": counts[0][0], "hubway_count": counts[1][0],
                             "open_count": counts[2][0], "tree_count": counts[3][0], "budget": counts[4][0]})
            folium.Marker(coords, popup=str(counts)).add_to(map_osm)

        repo.dropCollection("kmeansdata")
        repo.createCollection("kmeansdata")
        repo['jhs2018_rpm1995.kmeansdata'].insert_many(megalist)
        map_osm.save(filenamemap)

        repo.logout()

        endTime = datetime.datetime.now()

        return {"start": startTime, "end": endTime}

    @staticmethod
    def provenance(doc=prov.model.ProvDocument(), startTime=None, endTime=None):

            # Create the provenance document describing everything happening
            # in this script. Each run of the script will generate a new
            # document describing that invocation event.

        client = dml.pymongo.MongoClient()
        repo = client.repo
        repo.authenticate('jhs2018_rpm1995', 'jhs2018_rpm1995')
        doc.add_namespace('alg', 'http://datamechanics.io/algorithm/')  # The scripts are in <folder>#<filename> format.
        doc.add_namespace('dat', 'http://datamechanics.io/data/')  # The data sets are in <user>#<collection> format.
        doc.add_namespace('ont', 'http://datamechanics.io/ontology#')  # 'Extension', 'DataResource', 'DataSet',
        # 'Retrieval', 'Query', or 'Computation'.
        doc.add_namespace('log', 'http://datamechanics.io/log/')  # The event log.
        doc.add_namespace('bwod', 'https://boston.opendatasoft.com/explore/dataset/boston-neighborhoods/')  # Boston
        # Wicked Open Data
        doc.add_namespace('ab', 'https://data.boston.gov/dataset/boston-neighborhoods')   # Analyze Boston

        this_script = doc.agent('alg:jhs2018_rpm1995#Combine_Coordinates',
                                {prov.model.PROV_TYPE: prov.model.PROV['SoftwareAgent'], 'ont:Extension': 'py'})

# #######
        resource_greenassets = doc.entity('dat:jhs2018_rpm1995_greenassets',
                                  {prov.model.PROV_LABEL: 'Coordinates of Environment Friendly Assets in Boston',
                                   prov.model.PROV_TYPE: 'ont:DataSet'})

        get_grid = doc.activity('log:uuid' + str(uuid.uuid4()), startTime, endTime,
                                          {
                                                    prov.model.PROV_LABEL: "Locations of Green Assets in Boston in a "
                                                                           "grid representation",
                                                    prov.model.PROV_TYPE: 'ont:Computation'})

        doc.wasAssociatedWith(get_grid, this_script)

        doc.usage(get_grid, resource_greenassets, startTime)

# #######
        grid = doc.entity('dat:jhs2018_rpm1995_kmeans',
                                 {prov.model.PROV_LABEL: 'Coordinates of All Environment Friendly Assets in Grid',
                                  prov.model.PROV_TYPE: 'ont:DataSet'})
        doc.wasAttributedTo(grid, this_script)
        doc.wasGeneratedBy(grid, get_grid, endTime)
        doc.wasDerivedFrom(grid, resource_greenassets, get_grid, get_grid, get_grid)

        repo.logout()

        return doc


# display.execute()
# doc = display.provenance()
# print(doc.get_provn())
# print(json.dumps(json.loads(doc.serialize()), indent=4))

# eof
# Out:
# Now running display.py
# document
#   prefix alg <http://datamechanics.io/algorithm/>
#   prefix dat <http://datamechanics.io/data/>
#   prefix ont <http://datamechanics.io/ontology#>
#   prefix log <http://datamechanics.io/log/>
#   prefix bwod <https://boston.opendatasoft.com/explore/dataset/boston-neighborhoods/>
#   prefix ab <https://data.boston.gov/dataset/boston-neighborhoods>
#
#   agent(alg:jhs2018_rpm1995#Combine_Coordinates, [prov:type='prov:SoftwareAgent', ont:Extension="py"])
#   entity(dat:jhs2018_rpm1995_greenassets, [prov:label="Coordinates of Environment Friendly Assets in Boston", prov:type="ont:DataSet"])
#   activity(log:uuidd739b1c6-2aba-4e54-8ea7-673a7893162a, -, -, [prov:label="Locations of Green Assets in Boston in a grid representation", prov:type="ont:Computation"])
#   wasAssociatedWith(log:uuidd739b1c6-2aba-4e54-8ea7-673a7893162a, alg:jhs2018_rpm1995#Combine_Coordinates, -)
#   used(log:uuidd739b1c6-2aba-4e54-8ea7-673a7893162a, dat:jhs2018_rpm1995_greenassets, -)
#   entity(dat:jhs2018_rpm1995_kmeans, [prov:label="Coordinates of All Environment Friendly Assets in Grid", prov:type="ont:DataSet"])
#   wasAttributedTo(dat:jhs2018_rpm1995_kmeans, alg:jhs2018_rpm1995#Combine_Coordinates)
#   wasGeneratedBy(dat:jhs2018_rpm1995_kmeans, log:uuidd739b1c6-2aba-4e54-8ea7-673a7893162a, -)
#   wasDerivedFrom(dat:jhs2018_rpm1995_kmeans, dat:jhs2018_rpm1995_greenassets, log:uuidd739b1c6-2aba-4e54-8ea7-673a7893162a, log:uuidd739b1c6-2aba-4e54-8ea7-673a7893162a, log:uuidd739b1c6-2aba-4e54-8ea7-673a7893162a)
# endDocument
# {
#     "prefix": {
#         "alg": "http://datamechanics.io/algorithm/",
#         "dat": "http://datamechanics.io/data/",
#         "ont": "http://datamechanics.io/ontology#",
#         "log": "http://datamechanics.io/log/",
#         "bwod": "https://boston.opendatasoft.com/explore/dataset/boston-neighborhoods/",
#         "ab": "https://data.boston.gov/dataset/boston-neighborhoods"
#     },
#     "agent": {
#         "alg:jhs2018_rpm1995#Combine_Coordinates": {
#             "prov:type": {
#                 "$": "prov:SoftwareAgent",
#                 "type": "prov:QUALIFIED_NAME"
#             },
#             "ont:Extension": "py"
#         }
#     },
#     "entity": {
#         "dat:jhs2018_rpm1995_greenassets": {
#             "prov:label": "Coordinates of Environment Friendly Assets in Boston",
#             "prov:type": "ont:DataSet"
#         },
#         "dat:jhs2018_rpm1995_kmeans": {
#             "prov:label": "Coordinates of All Environment Friendly Assets in Grid",
#             "prov:type": "ont:DataSet"
#         }
#     },
#     "activity": {
#         "log:uuidd739b1c6-2aba-4e54-8ea7-673a7893162a": {
#             "prov:label": "Locations of Green Assets in Boston in a grid representation",
#             "prov:type": "ont:Computation"
#         }
#     },
#     "wasAssociatedWith": {
#         "_:id1": {
#             "prov:activity": "log:uuidd739b1c6-2aba-4e54-8ea7-673a7893162a",
#             "prov:agent": "alg:jhs2018_rpm1995#Combine_Coordinates"
#         }
#     },
#     "used": {
#         "_:id2": {
#             "prov:activity": "log:uuidd739b1c6-2aba-4e54-8ea7-673a7893162a",
#             "prov:entity": "dat:jhs2018_rpm1995_greenassets"
#         }
#     },
#     "wasAttributedTo": {
#         "_:id3": {
#             "prov:entity": "dat:jhs2018_rpm1995_kmeans",
#             "prov:agent": "alg:jhs2018_rpm1995#Combine_Coordinates"
#         }
#     },
#     "wasGeneratedBy": {
#         "_:id4": {
#             "prov:entity": "dat:jhs2018_rpm1995_kmeans",
#             "prov:activity": "log:uuidd739b1c6-2aba-4e54-8ea7-673a7893162a"
#         }
#     },
#     "wasDerivedFrom": {
#         "_:id5": {
#             "prov:generatedEntity": "dat:jhs2018_rpm1995_kmeans",
#             "prov:usedEntity": "dat:jhs2018_rpm1995_greenassets",
#             "prov:activity": "log:uuidd739b1c6-2aba-4e54-8ea7-673a7893162a",
#             "prov:generation": "log:uuidd739b1c6-2aba-4e54-8ea7-673a7893162a",
#             "prov:usage": "log:uuidd739b1c6-2aba-4e54-8ea7-673a7893162a"
#         }
#     }
# }
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:127: DeprecationWarning: Database.logout() is deprecated
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:178: DeprecationWarning: Database.logout() is deprecated
